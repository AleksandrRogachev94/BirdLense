# %%
from ultralytics import YOLO

# %%
model = YOLO("../app/processor/models/classification/nabirds_yolov11n_cls/weights/best.pt")  # path to your trained classification model

# %%
model = YOLO("yolo11n.pt")  # path to your trained classification model

# %%
image_url = "/Users/alexrogachev/Downloads/video.mp4"

results = model.track(image_url, imgsz=320, stream=False, show=True, classes=[14],   # bird
    conf=0.25)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/653) /Users/alexrogachev/Downloads/video.mp4: 192x320 1 bird, 21.7ms
# video 1/1 (frame 2/653) /Users/alexrogachev/Downloads/video.mp4: 192x320 1 bird, 19.9ms
# video 1/1 (frame 3/653) /Users/alexrogachev/Downloads/video.mp4: 192x320 1 bird, 21.4ms
# video 1/1 (frame 4/653) /Users/alexrogachev/Downloads/video.mp4: 192x320 1 bird, 18.3ms
# ...

# %%
image_url = "/Users/alexrogachev/Desktop/test_screen.png"

results = model(image_url)
# Out:
# image 1/1 /Users/alexrogachev/Desktop/test_screen.png: 224x224 Gray_Catbird 0.18, Common_Raven 0.12, Brown-headed_Cowbird_(Male) 0.09, Brewer's_Blackbird_(Male) 0.08, Great-tailed_Grackle 0.06, 18.4ms
# Speed: 8.6ms preprocess, 18.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
r = results[0]

top5 = r.probs.top5
top5_conf = r.probs.top5conf

for idx, conf in zip(top5, top5_conf):
    class_name = model.names[int(idx)]
    print(f"{class_name}: {float(conf):.4f}")
# Out:
# Gray_Catbird: 0.1759
# Common_Raven: 0.1160
# Brown-headed_Cowbird_(Male): 0.0939
# Brewer's_Blackbird_(Male): 0.0814
# Great-tailed_Grackle: 0.0611

# %%
results
