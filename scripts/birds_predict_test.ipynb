# %%
from ultralytics import YOLO

# %%
model = YOLO("../app/processor/models/classification/nabirds_yolo11n_cls/weights/best_ncnn_model", task="classify")  # path to your trained classification model

# %%
model = YOLO("../app/processor/models/detection/nabirds_yolo11n_binary/weights/best_ncnn_model", task="detect")  # path to your trained classification model

# %%
model = YOLO("/Users/alex/Downloads/nabirds_v1_results/weights/best.pt", task="detect")  # path to your trained classification model

# %%
model = YOLO("yolo11n.pt")  # path to your trained classification model

# %%
image_url = "/Users/alex/Downloads/manybirds.mp4"

results = model.track(image_url, imgsz=320, stream=False, show=True, #classes=[14],   # bird
    conf=0.1, iou=0.4)

# %%
image_url = "/Users/alex/Downloads/llm_verification_logs/20260104_221628_track2.jpg"

results = model(image_url, task="classsify")

# %%
r = results[0]

top5 = r.probs.top5
top5_conf = r.probs.top5conf

for idx, conf in zip(top5, top5_conf):
    class_name = model.names[int(idx)]
    print(f"{class_name}: {float(conf):.4f}")

# %%
results

# %% [markdown]
# ## Export

# %%
model = YOLO("../app/processor/models/detection/nabirds_yolo11n_binary/weights/best.pt", task="detect")  # path to your trained classification model

# %%
model.export(format='ncnn', imgsz=320, half=True)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.8 torch-2.9.1 CPU (Apple M4)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '../app/processor/models/detection/nabirds_yolo11n_binary/weights/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 5, 2100) (5.2 MB)
#
# NCNN: starting export with NCNN 1.0.20250916 and PNNX 20251119...
# pnnxparam = ../app/processor/models/detection/nabirds_yolo11n_binary/weights/best_ncnn_model/model.pnnx.param
# pnnxbin = ../app/processor/models/detection/nabirds_yolo11n_binary/weights/best_ncnn_model/model.pnnx.bin
# pnnxpy = ../app/processor/models/detection/nabirds_yolo11n_binary/weights/best_ncnn_model/model_pnnx.py
# pnnxonnx = ../app/processor/models/detection/nabirds_yolo11n_binary/weights/best_ncnn_model/model.pnnx.onnx
# ncnnparam = ../app/processor/models/detection/nabirds_yolo11n_binary/weights/best_ncnn_model/model.ncnn.param
# ...
